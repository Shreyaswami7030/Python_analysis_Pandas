# %% [raw]
# Pandas is used in handling the missing values
#
# # imputing :- missing values means==> replace the missing values
# # Droping the missing values :-  in a large dataset if there is missing values then drop the values.

# %%
import numpy as np

# %%
import pandas as pd

# %%
array=np.random.randint(40,60,size=(10,6))
array
# Out:
# array([[53, 48, 53, 54, 52, 54],
#        [42, 57, 59, 48, 54, 45],
#        [45, 45, 44, 56, 46, 57],
#        [53, 56, 47, 41, 45, 58],
#        [57, 40, 45, 53, 46, 44],
#        [43, 49, 45, 50, 49, 40],
#        [47, 49, 53, 43, 59, 49],
#        [51, 50, 43, 49, 42, 43],
#        [50, 42, 41, 48, 46, 46],
#        [54, 46, 47, 51, 52, 56]])

# %%
df=pd.DataFrame(array,columns=list("shreya"))                     # crating a dataframe
df
# Out:
#     s   h   r   e   y   a
# 0  53  48  53  54  52  54
# 1  42  57  59  48  54  45
# 2  45  45  44  56  46  57
# 3  53  56  47  41  45  58
# 4  57  40  45  53  46  44
# 5  43  49  45  50  49  40
# 6  47  49  53  43  59  49
# 7  51  50  43  49  42  43
# 8  50  42  41  48  46  46
# 9  54  46  47  51  52  56

# %%
df.iloc[5:8,[1,3,4]]                           # differnece betwen iloc and loc.
# Out:
#     h   e   y
# 5  49  50  49
# 6  49  43  59
# 7  50  49  42

# %%
df.iloc[3:6]
# Out:
#     s   h   r   e   y   a
# 3  53  56  47  41  45  58
# 4  57  40  45  53  46  44
# 5  43  49  45  50  49  40

# %%
df.loc[5:8,list["shr"]]
# Out:
#     s   h   r   e   y   a
# 5  43  49  45  50  49  40
# 6  47  49  53  43  59  49
# 7  51  50  43  49  42  43
# 8  50  42  41  48  46  46

# %%
df.loc[5:8,list["s","h","r"]]
# Out:
#     s   h   r   e   y   a
# 5  43  49  45  50  49  40
# 6  47  49  53  43  59  49
# 7  51  50  43  49  42  43
# 8  50  42  41  48  46  46

# %%
# Manually adding missing values.

# %%
df.iloc[1,1]=np.nan
df.iloc[4:7,2]=np.nan
df.iloc[3,3]=np.nan
df.iloc[4,5]=np.nan
df.iloc[7,4]=np.nan
df.iloc[1,5]=np.nan
df
# Out:
#     s     h     r     e     y     a
# 0  53  48.0  53.0  54.0  52.0  54.0
# 1  42   NaN  59.0  48.0  54.0   NaN
# 2  45  45.0  44.0  56.0  46.0  57.0
# 3  53  56.0  47.0   NaN  45.0  58.0
# 4  57  40.0   NaN  53.0  46.0   NaN
# 5  43  49.0   NaN  50.0  49.0  40.0
# 6  47  49.0   NaN  43.0  59.0  49.0
# 7  51  50.0  43.0  49.0   NaN  43.0
# 8  50  42.0  41.0  48.0  46.0  46.0
# 9  54  46.0  47.0  51.0  52.0  56.0

# %%
df.isnull()
# Out:
#        s      h      r      e      y      a
# 0  False  False  False  False  False  False
# 1  False   True  False  False  False   True
# 2  False  False  False  False  False  False
# 3  False  False  False   True  False  False
# 4  False  False   True  False  False   True
# 5  False  False   True  False  False  False
# 6  False  False   True  False  False  False
# 7  False  False  False  False   True  False
# 8  False  False  False  False  False  False
# 9  False  False  False  False  False  False

# %%
df.isnull().sum()     # showing is coulmn null values.
# Out:
# s    0
# h    1
# r    3
# e    1
# y    1
# a    2
# dtype: int64

# %%
df["r"].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: r, dtype: bool

# %%
df["a"].isnull().sum()
# Out:
# 2

# %%
df.isna().mean()*100
# Out:
# s     0.0
# h    10.0
# r    30.0
# e    10.0
# y    10.0
# a    20.0
# dtype: float64

# %%
df.dropna()           #  bydefault it will be drop all the rows containig "Nan" Values
# Out:
#     s     h     r     e     y     a
# 0  53  48.0  53.0  54.0  52.0  54.0
# 2  45  45.0  44.0  56.0  46.0  57.0
# 8  50  42.0  41.0  48.0  46.0  46.0
# 9  54  46.0  47.0  51.0  52.0  56.0

# %%
df.iloc[4,1]=np.nan

# %%
df
# Out:
#     s     h     r     e     y     a
# 0  53  48.0  53.0  54.0  52.0  54.0
# 1  42   NaN  59.0  48.0  54.0   NaN
# 2  45  45.0  44.0  56.0  46.0  57.0
# 3  53  56.0  47.0   NaN  45.0  58.0
# 4  57   NaN   NaN  53.0  46.0   NaN
# 5  43  49.0   NaN  50.0  49.0  40.0
# 6  47  49.0   NaN  43.0  59.0  49.0
# 7  51  50.0  43.0  49.0   NaN  43.0
# 8  50  42.0  41.0  48.0  46.0  46.0
# 9  54  46.0  47.0  51.0  52.0  56.0

# %%
df.dropna(thresh=6)         # 6 non null values(no null value)         :-  thresh is paramter.
# Out:
#     s     h     r     e     y     a
# 0  53  48.0  53.0  54.0  52.0  54.0
# 2  45  45.0  44.0  56.0  46.0  57.0
# 8  50  42.0  41.0  48.0  46.0  46.0
# 9  54  46.0  47.0  51.0  52.0  56.0

# %%
df.dropna(thresh=2)
# Out:
#     s     h     r     e     y     a
# 0  53  48.0  53.0  54.0  52.0  54.0
# 1  42   NaN  59.0  48.0  54.0   NaN
# 2  45  45.0  44.0  56.0  46.0  57.0
# 3  53  56.0  47.0   NaN  45.0  58.0
# 4  57   NaN   NaN  53.0  46.0   NaN
# 5  43  49.0   NaN  50.0  49.0  40.0
# 6  47  49.0   NaN  43.0  59.0  49.0
# 7  51  50.0  43.0  49.0   NaN  43.0
# 8  50  42.0  41.0  48.0  46.0  46.0
# 9  54  46.0  47.0  51.0  52.0  56.0

# %%
df.dropna(axis=1)      # null values gives axix=1 it there is no null values  from column give the dataframe.
# Out:
#     s
# 0  53
# 1  42
# 2  45
# 3  53
# 4  57
# 5  43
# 6  47
# 7  51
# 8  50
# 9  54

# %%
df.dropna(thresh=8,axis=1)       #  there is 10 recordes where thresh is 8 which means not null . and reamining 2 is null values.
# Out:
#     s     h     e     y     a
# 0  53  48.0  54.0  52.0  54.0
# 1  42   NaN  48.0  54.0   NaN
# 2  45  45.0  56.0  46.0  57.0
# 3  53  56.0   NaN  45.0  58.0
# 4  57   NaN  53.0  46.0   NaN
# 5  43  49.0  50.0  49.0  40.0
# 6  47  49.0  43.0  59.0  49.0
# 7  51  50.0  49.0   NaN  43.0
# 8  50  42.0  48.0  46.0  46.0
# 9  54  46.0  51.0  52.0  56.0

# %%
# How to drop a column

# %%
df1 =df.drop("y",axis=1)     # bydefault inplace=false                # x: - is the all features
df1                                                                  # y= :- is target coulmn
# Out:
#     s     h     r     e     a
# 0  53  48.0  53.0  54.0  54.0
# 1  42   NaN  59.0  48.0   NaN
# 2  45  45.0  44.0  56.0  57.0
# 3  53  56.0  47.0   NaN  58.0
# 4  57   NaN   NaN  53.0   NaN
# 5  43  49.0   NaN  50.0  40.0
# 6  47  49.0   NaN  43.0  49.0
# 7  51  50.0  43.0  49.0  43.0
# 8  50  42.0  41.0  48.0  46.0
# 9  54  46.0  47.0  51.0  56.0

# %%
# No Need to assign new variables, , inplace= True
df.drop("s",axis=1,inplace=True)
df
# Out:
#       h     r     e     y     a
# 0  48.0  53.0  54.0  52.0  54.0
# 1   NaN  59.0  48.0  54.0   NaN
# 2  45.0  44.0  56.0  46.0  57.0
# 3  56.0  47.0   NaN  45.0  58.0
# 4   NaN   NaN  53.0  46.0   NaN
# 5  49.0   NaN  50.0  49.0  40.0
# 6  49.0   NaN  43.0  59.0  49.0
# 7  50.0  43.0  49.0   NaN  43.0
# 8  42.0  41.0  48.0  46.0  46.0
# 9  46.0  47.0  51.0  52.0  56.0

# %%
df
# Out:
#       h     r     e     y     a
# 0  48.0  53.0  54.0  52.0  54.0
# 1   NaN  59.0  48.0  54.0   NaN
# 2  45.0  44.0  56.0  46.0  57.0
# 3  56.0  47.0   NaN  45.0  58.0
# 4   NaN   NaN  53.0  46.0   NaN
# 5  49.0   NaN  50.0  49.0  40.0
# 6  49.0   NaN  43.0  59.0  49.0
# 7  50.0  43.0  49.0   NaN  43.0
# 8  42.0  41.0  48.0  46.0  46.0
# 9  46.0  47.0  51.0  52.0  56.0

# %%
df=df.drop(["h","e"],axis=1)
df
# Out:
#       r     y     a
# 0  53.0  52.0  54.0
# 1  59.0  54.0   NaN
# 2  44.0  46.0  57.0
# 3  47.0  45.0  58.0
# 4   NaN  46.0   NaN
# 5   NaN  49.0  40.0
# 6   NaN  59.0  49.0
# 7  43.0   NaN  43.0
# 8  41.0  46.0  46.0
# 9  47.0  52.0  56.0

# %%
df.fillna(100)     # repalcing the null values insted of 100
# Out:
#        r      y      a
# 0   53.0   52.0   54.0
# 1   59.0   54.0  100.0
# 2   44.0   46.0   57.0
# 3   47.0   45.0   58.0
# 4  100.0   46.0  100.0
# 5  100.0   49.0   40.0
# 6  100.0   59.0   49.0
# 7   43.0  100.0   43.0
# 8   41.0   46.0   46.0
# 9   47.0   52.0   56.0

# %%
df=pd.read_csv("medical_insurance - medical_insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
import numpy as np

# %%
import pandas as pd

# %%
df.iloc[2:5,3:6]=np.nan
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900       0.0    yes  southwest  16884.92400
# 1      18    male  33.770       1.0     no  southeast   1725.55230
# 2      28    male  33.000       NaN    NaN        NaN   4449.46200
# 3      33    male  22.705       NaN    NaN        NaN  21984.47061
# 4      32    male  28.880       NaN    NaN        NaN   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970       3.0     no  northwest  10600.54830
# 1334   18  female  31.920       0.0     no  northeast   2205.98080
# 1335   18  female  36.850       0.0     no  southeast   1629.83350
# 1336   21  female  25.800       0.0     no  southwest   2007.94500
# 1337   61  female  29.070       0.0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isna().sum()      # Excute this main query
# Out:
# age         0
# sex         0
# bmi         0
# children    3
# smoker      3
# region      3
# charges     0
# dtype: int64

# %%
df["children"].value_counts()
# Out:
# children
# 0.0    572
# 1.0    324
# 2.0    240
# 3.0    156
# 4.0     25
# 5.0     18
# Name: count, dtype: int64

# %%
df["children"].fillna(df["children"].median(),inplace=True)     # where the childer data is numeric then is used median.
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\1675589012.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["children"].fillna(df["children"].median(),inplace=True)

# %%
df["smoker"].fillna("no",inplace=True)       #   convert into string
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\1283291334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["smoker"].fillna("no",inplace=True)

# %%
df["smoker"].value_counts()
# Out:
# smoker
# no     1061
# yes     274
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# southeast    363
# southwest    325
# northeast    324
# northwest    323
# Name: count, dtype: int64

# %%
df["region"].fillna("southeast",inplace=True)     # permant replace then used inplace=True
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\1473569024.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["region"].fillna("southeast",inplace=True)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    3
# smoker      3
# region      3
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1335 non-null   float64
#  4   smoker    1335 non-null   object
#  5   region    1335 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
df1=pd.read_excel("autos_dataset.xlsx")
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
lst=df1.columns
lst
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
for i in lst:
    print(df1[i].value_counts())
    print("*"*100)
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# ****************************************************************************************************
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64
# ****************************************************************************************************
# make
# ...

# %%
df1.replace("?",np.nan,inplace=True)     # it is replacing null values.
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\1369444529.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1.replace("?",np.nan,inplace=True)

# %%
df1.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df1["price"].value_counts(dict)
# Out:
# price
# 8921.0     0.009950
# 18150.0    0.009950
# 8845.0     0.009950
# 8495.0     0.009950
# 7609.0     0.009950
#              ...
# 45400.0    0.004975
# 16503.0    0.004975
# 5389.0     0.004975
# 6189.0     0.004975
# 22625.0    0.004975
# Name: proportion, Length: 186, dtype: float64

# %%
df1["normalized-losses"].value_counts()
# Out:
# normalized-losses
# 161.0    11
# 91.0      8
# 150.0     7
# 128.0     6
# 134.0     6
# 104.0     6
# 95.0      5
# 102.0     5
# 103.0     5
# 74.0      5
# 85.0      5
# 168.0     5
# 94.0      5
# 65.0      5
# 106.0     4
# 122.0     4
# 148.0     4
# 118.0     4
# 93.0      4
# 101.0     3
# 125.0     3
# 137.0     3
# 154.0     3
# 83.0      3
# 115.0     3
# 119.0     2
# 87.0      2
# 194.0     2
# 197.0     2
# 108.0     2
# 89.0      2
# 164.0     2
# 158.0     2
# 145.0     2
# 192.0     2
# 188.0     2
# 81.0      2
# 110.0     2
# 113.0     2
# 129.0     2
# 153.0     2
# 107.0     1
# 78.0      1
# 186.0     1
# 231.0     1
# 77.0      1
# 98.0      1
# 121.0     1
# 90.0      1
# 142.0     1
# 256.0     1
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df1["normalized-losses"].fillna(df1["normalized-losses"].median(),inplace=True)     # replcae the normalized losses column .
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\3541924269.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["normalized-losses"].fillna(df1["normalized-losses"].median(),inplace=True)

# %%
df1["price"].fillna(df1["price"].median(),inplace=True)       # replacing null values
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1656\359317471.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["price"].fillna(df1["price"].median(),inplace=True)

# %%
df1.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# # Crosstab()   :- it give to  analysis of total  2 column

# %%
pd.crosstab(df1["fuel-type"],df1["price"])      # it give summary or analysis two colummns
# Out:
# price      5118.0   5151.0   5195.0   5348.0   5389.0   5399.0   5499.0   \
# fuel-type
# diesel           0        0        0        0        0        0        0
# gas              1        1        1        1        1        1        1
#
# price      5572.0   6095.0   6189.0   ...  34028.0  34184.0  35056.0  35550.0  \
# fuel-type                             ...
# diesel           0        0        0  ...        0        0        0        0
# gas              2        1        1  ...        1        1        1        1
#
# price      36000.0  36880.0  37028.0  40960.0  41315.0  45400.0
# fuel-type
# diesel           0        0        0        0        0        0
# gas              1        1        1        1        1        1
#
# [2 rows x 186 columns]

# %%
pd.crosstab(df1["fuel-type"],df1["price"]).to_dict()     # $ to give dictionary formate
# Out:
# {5118.0: {'diesel': 0, 'gas': 1},
#  5151.0: {'diesel': 0, 'gas': 1},
#  5195.0: {'diesel': 0, 'gas': 1},
#  5348.0: {'diesel': 0, 'gas': 1},
#  5389.0: {'diesel': 0, 'gas': 1},
#  5399.0: {'diesel': 0, 'gas': 1},
#  5499.0: {'diesel': 0, 'gas': 1},
#  5572.0: {'diesel': 0, 'gas': 2},
#  6095.0: {'diesel': 0, 'gas': 1},
#  6189.0: {'diesel': 0, 'gas': 1},
#  6229.0: {'diesel': 0, 'gas': 2},
#  6295.0: {'diesel': 0, 'gas': 1},
#  6338.0: {'diesel': 0, 'gas': 1},
#  6377.0: {'diesel': 0, 'gas': 1},
#  6479.0: {'diesel': 0, 'gas': 1},
#  6488.0: {'diesel': 0, 'gas': 1},
#  6529.0: {'diesel': 0, 'gas': 1},
#  6575.0: {'diesel': 0, 'gas': 1},
#  6649.0: {'diesel': 0, 'gas': 1},
#  6669.0: {'diesel': 0, 'gas': 1},
#  6692.0: {'diesel': 0, 'gas': 2},
#  6695.0: {'diesel': 0, 'gas': 1},
#  6785.0: {'diesel': 0, 'gas': 1},
#  6795.0: {'diesel': 0, 'gas': 1},
#  6849.0: {'diesel': 0, 'gas': 1},
#  6855.0: {'diesel': 0, 'gas': 1},
#  6918.0: {'diesel': 0, 'gas': 1},
# ...

# %%
df1["drive-wheels"].value_counts().to_dict()    # particular column in dictonary formate.
# Out:
# {'fwd': 120, 'rwd': 76, '4wd': 9}

# %%
import seaborn as sns
sns.countplot(x=df1["fuel-type"])
# Out:
# <Axes: xlabel='fuel-type', ylabel='count'>

# %%
df1 ["fuel-type"].value_counts()
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %% [markdown]
# # Pandas Sorting Function

# %%
df4=pd.DataFrame(array,columns=list("shreya"))                     # crating a dataframe
df4
# Out:
#     s   h   r   e   y   a
# 0  53  48  53  54  52  54
# 1  42  57  59  48  54  45
# 2  45  45  44  56  46  57
# 3  53  56  47  41  45  58
# 4  57  40  45  53  46  44
# 5  43  49  45  50  49  40
# 6  47  49  53  43  59  49
# 7  51  50  43  49  42  43
# 8  50  42  41  48  46  46
# 9  54  46  47  51  52  56

# %%
df4.index=list("MachineDSA")       # changing the row values
df4
# Out:
#     s   h   r   e   y   a
# M  53  48  53  54  52  54
# a  42  57  59  48  54  45
# c  45  45  44  56  46  57
# h  53  56  47  41  45  58
# i  57  40  45  53  46  44
# n  43  49  45  50  49  40
# e  47  49  53  43  59  49
# D  51  50  43  49  42  43
# S  50  42  41  48  46  46
# A  54  46  47  51  52  56

# %%
df4.sort_index()    # Sord dataframe
# Out:
#     s   h   r   e   y   a
# A  54  46  47  51  52  56
# D  51  50  43  49  42  43
# M  53  48  53  54  52  54
# S  50  42  41  48  46  46
# a  42  57  59  48  54  45
# c  45  45  44  56  46  57
# e  47  49  53  43  59  49
# h  53  56  47  41  45  58
# i  57  40  45  53  46  44
# n  43  49  45  50  49  40

# %%
df1.sort_index(axis=1)            # column indexing sort
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# 3          std        sedan  3.19        24               10.0         2337
# 4          std        sedan  3.19        18                8.0         2824
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78        23                9.5         2952
# 201      turbo        sedan  3.78        19                8.7         3049
# 202        std        sedan  3.58        18                8.8         3012
# 203      turbo        sedan  3.01        26               23.0         3217
# 204      turbo        sedan  3.78        19                9.5         3062
#
# ...

# %%
df1
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              115.0  alfa-romero       gas        std
# 1            3              115.0  alfa-romero       gas        std
# 2            1              115.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df1.sort_values("wheel-base")
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 31           2              137.0          honda       gas        std
# 30           2              137.0          honda       gas        std
# 18           2              121.0      chevrolet       gas        std
# 0            3              115.0    alfa-romero       gas        std
# 1            3              115.0    alfa-romero       gas        std
# ..         ...                ...            ...       ...        ...
# 113          0              115.0         peugot       gas        std
# 114          0              115.0         peugot    diesel      turbo
# 71          -1              115.0  mercedes-benz       gas        std
# 70          -1               93.0  mercedes-benz    diesel      turbo
# 73           0              115.0  mercedes-benz       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %% [markdown]
# # Sorting Method           11/06/24

# %%
import numpy as np

# %%
import pandas as pd

# %%
array=np.random.randint(40,60,size=(10,6))
array
# Out:
# array([[43, 42, 53, 42, 52, 55],
#        [58, 43, 46, 51, 47, 48],
#        [47, 53, 53, 42, 59, 45],
#        [43, 54, 52, 50, 58, 51],
#        [48, 54, 40, 48, 47, 52],
#        [54, 54, 41, 51, 54, 49],
#        [45, 57, 45, 43, 43, 57],
#        [59, 46, 42, 41, 46, 51],
#        [45, 56, 41, 41, 55, 51],
#        [46, 59, 51, 41, 59, 48]])

# %%
df=pd.DataFrame(array,columns=list("shreya"))                     # crating a dataframe
df
# Out:
#     s   h   r   e   y   a
# 0  43  42  53  42  52  55
# 1  58  43  46  51  47  48
# 2  47  53  53  42  59  45
# 3  43  54  52  50  58  51
# 4  48  54  40  48  47  52
# 5  54  54  41  51  54  49
# 6  45  57  45  43  43  57
# 7  59  46  42  41  46  51
# 8  45  56  41  41  55  51
# 9  46  59  51  41  59  48

# %%
df.sort_index(axis=0)
# Out:
#     s   h   r   e   y   a
# 0  43  42  53  42  52  55
# 1  58  43  46  51  47  48
# 2  47  53  53  42  59  45
# 3  43  54  52  50  58  51
# 4  48  54  40  48  47  52
# 5  54  54  41  51  54  49
# 6  45  57  45  43  43  57
# 7  59  46  42  41  46  51
# 8  45  56  41  41  55  51
# 9  46  59  51  41  59  48

# %%
df.sort_index(axis=1)
df
# Out:
#     s   h   r   e   y   a
# 0  43  42  53  42  52  55
# 1  58  43  46  51  47  48
# 2  47  53  53  42  59  45
# 3  43  54  52  50  58  51
# 4  48  54  40  48  47  52
# 5  54  54  41  51  54  49
# 6  45  57  45  43  43  57
# 7  59  46  42  41  46  51
# 8  45  56  41  41  55  51
# 9  46  59  51  41  59  48

# %%
df
# Out:
#     s   h   r   e   y   a
# 0  43  42  53  42  52  55
# 1  58  43  46  51  47  48
# 2  47  53  53  42  59  45
# 3  43  54  52  50  58  51
# 4  48  54  40  48  47  52
# 5  54  54  41  51  54  49
# 6  45  57  45  43  43  57
# 7  59  46  42  41  46  51
# 8  45  56  41  41  55  51
# 9  46  59  51  41  59  48

# %%
df.sort_values("h")
# Out:
#     s   h   r   e   y   a
# 0  43  42  53  42  52  55
# 1  58  43  46  51  47  48
# 7  59  46  42  41  46  51
# 2  47  53  53  42  59  45
# 3  43  54  52  50  58  51
# 4  48  54  40  48  47  52
# 5  54  54  41  51  54  49
# 8  45  56  41  41  55  51
# 6  45  57  45  43  43  57
# 9  46  59  51  41  59  48

# %%
df11=pd.read_csv("medical_insurance - medical_insurance.csv")
df11
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df11.sort_values("bmi")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 428    21  female  16.815         1     no  northeast   3167.45585
# 1226   38    male  16.815         2     no  northeast   6640.54485
# 412    26  female  17.195         2    yes  northeast  14455.64405
# 1286   28  female  17.290         0     no  northeast   3732.62510
# ...   ...     ...     ...       ...    ...        ...          ...
# 286    46  female  48.070         2     no  northeast   9432.92530
# 116    58    male  49.060         0     no  southeast  11381.32540
# 847    23    male  50.380         1     no  southeast   2438.05520
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 1317   18    male  53.130         0     no  southeast   1163.46270
#
# [1338 rows x 7 columns]

# %%
df11=df11.sort_values("charges",ascending=False)  # ascending  false means data in descending
df11
# Out:
#       age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 22     18    male  34.100         0     no  southeast   1137.01100
# 663    18    male  33.660         0     no  southeast   1136.39940
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 808    18    male  30.140         0     no  southeast   1131.50660
# 940    18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %%
df11.reset_index(drop=True)     # deleting the index column.
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      54  female  47.410         0    yes  southeast  63770.42801
# 1      45    male  30.360         0    yes  southeast  62592.87309
# 2      52    male  34.485         3    yes  northwest  60021.39897
# 3      31  female  38.095         1    yes  northeast  58571.07448
# 4      33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   18    male  34.100         0     no  southeast   1137.01100
# 1334   18    male  33.660         0     no  southeast   1136.39940
# 1335   18    male  33.330         0     no  southeast   1135.94070
# 1336   18    male  30.140         0     no  southeast   1131.50660
# 1337   18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Pandas Group by Function

# %%
df11.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df11['region'].value_counts()
# Out:
# region
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df11["region"].nunique()
# Out:
# 4

# %%
df11.groupby("region").first()     # grouping the columun and adding the first index.
# Out:
#            age     sex     bmi  children smoker      charges
# region
# northeast   31  female  38.095         1    yes  58571.07448
# northwest   52    male  34.485         3    yes  60021.39897
# southeast   54  female  47.410         0    yes  63770.42801
# southwest   60    male  32.800         0    yes  52590.82939

# %%
df11.groupby("region").get_group("southwest")       # it is finding out particular columns ..with nunique values.
# Out:
#       age     sex   bmi  children smoker     region      charges
# 1146   60    male  32.8         0    yes  southwest  52590.82939
# 34     28    male  36.4         1    yes  southwest  51194.55914
# 175    63  female  37.7         0    yes  southwest  48824.45000
# 39     60    male  39.9         0    yes  southwest  48173.36100
# 328    64  female  33.8         1    yes  southwest  47928.03000
# ...   ...     ...   ...       ...    ...        ...          ...
# 487    19    male  28.7         0     no  southwest   1253.93600
# 791    19    male  27.6         0     no  southwest   1252.40700
# 584    19    male  20.7         0     no  southwest   1242.81600
# 681    19    male  20.3         0     no  southwest   1242.26000
# 1251   19    male  19.8         0     no  southwest   1241.56500
#
# [325 rows x 7 columns]

# %%
df11['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df11["children"].nunique()
# Out:
# 6

# %%
df11.groupby(["sex","children"] ).first()
# Out:
#                  age     bmi smoker     region      charges
# sex    children
# female 0          54  47.410    yes  southeast  63770.42801
#        1          31  38.095    yes  northeast  58571.07448
#        2          63  32.200    yes  southwest  47305.30500
#        3          53  36.860    yes  northwest  46661.44240
#        4          61  33.330     no  southeast  36580.28216
#        5          39  18.300    yes  southwest  19023.26000
# male   0          45  30.360    yes  southeast  62592.87309
#        1          28  36.400    yes  southwest  51194.55914
#        2          64  36.960    yes  southeast  49577.66240
#        3          52  34.485    yes  northwest  60021.39897
#        4          37  34.100    yes  southwest  40182.24600
#        5          43  25.520     no  southeast  14478.33015

# %%
df11.groupby(["sex","children"]).get_group(("female",1))                   # multiple value group by values.
# Out:
#      age     sex     bmi  children smoker     region      charges
# 577   31  female  38.095         1    yes  northeast  58571.07448
# 330   61  female  36.385         1    yes  northeast  48517.56315
# 328   64  female  33.800         1    yes  southwest  47928.03000
# 288   59  female  36.765         1    yes  northeast  47896.79135
# 587   34  female  30.210         1    yes  northwest  43943.87610
# ..   ...     ...     ...       ...    ...        ...          ...
# 363   21  female  26.400         1     no  southwest   2597.77900
# 680   21  female  17.400         1     no  southwest   2585.26900
# 106   19  female  28.400         1     no  southwest   2331.51900
# 571   18  female  37.290         1     no  southeast   2219.44510
# 469   18  female  24.090         1     no  southeast   2201.09710
#
# [158 rows x 7 columns]

# %%
df11.groupby(["sex","region"]).get_group(("female","southeast"))
# Out:
#       age     sex    bmi  children smoker     region      charges
# 543    54  female  47.41         0    yes  southeast  63770.42801
# 488    44  female  38.06         0    yes  southeast  48885.13561
# 674    44  female  43.89         2    yes  southeast  46200.98510
# 549    43  female  46.20         0    yes  southeast  45863.20500
# 845    60  female  32.45         0    yes  southeast  45008.95550
# ...   ...     ...    ...       ...    ...        ...          ...
# 1335   18  female  36.85         0     no  southeast   1629.83350
# 482    18  female  31.35         0     no  southeast   1622.18850
# 822    18  female  31.13         0     no  southeast   1621.88270
# 236    18  female  26.73         0     no  southeast   1615.76670
# 359    18  female  20.79         0     no  southeast   1607.51010
#
# [175 rows x 7 columns]

# %%
df12=pd.read_csv("Action_movies - Action_movies.csv")
df12
# Out:
#      Unnamed: 0  star_rating                                            title  \
# 0             0          9.0                                  The Dark Knight
# 1             1          8.8                                        Inception
# 2             2          8.8   Star Wars: Episode V - The Empire Strikes Back
# 3             3          8.7                                        Star Wars
# 4             4          8.7                                       The Matrix
# ..          ...          ...                                              ...
# 131         131          7.5                                   Running Scared
# 132         132          7.4                                            X-Men
# 133         133          7.4                                  La Femme Nikita
# 134         134          7.4                                         The Rock
# 135         135          7.4  Master and Commander: The Far Side of the World
#
# ...

# %%
# Find first 5  action movies "title" only with content rating R , sorted with star_rating in descending order

# %%
df12.groupby(["genre","content_rating"]).get_group(("Action","R")).sort_values("star_rating",ascending=False).head()
# Out:
#     Unnamed: 0  star_rating                       title content_rating  \
# 4            4          8.7                  The Matrix              R
# 5            5          8.6         Saving Private Ryan              R
# 8            8          8.5                   Gladiator              R
# 9            9          8.5  Terminator 2: Judgment Day              R
# 10          10          8.4                      Aliens              R
#
#      genre  duration                                        actors_list
# 4   Action       136  [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# 5   Action       169     [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 8   Action       155  [u'Russell Crowe', u'Joaquin Phoenix', u'Conni...
# 9   Action       137  [u'Arnold Schwarzenegger', u'Linda Hamilton', ...
# 10  Action       137  [u'Sigourney Weaver', u'Michael Biehn', u'Carr...

# %%
x=df12.groupby(["genre","content_rating"]).get_group(("Action","R")).sort_values("star_rating",ascending=False).head()["title"].to_list()

# %%
x                                          # it gives list fromate only title columns.
# Out:
# ['The Matrix',
#  'Saving Private Ryan',
#  'Gladiator',
#  'Terminator 2: Judgment Day',
#  'Aliens']

# %%
df12["star_rating"].value_counts()
# Out:
# star_rating
# 7.6    25
# 7.8    21
# 7.7    18
# 8.1    12
# 7.9    11
# 8.0    10
# 7.5    10
# 8.3     7
# 8.4     4
# 8.2     4
# 7.4     4
# 8.5     3
# 8.8     2
# 8.7     2
# 8.6     2
# 9.0     1
# Name: count, dtype: int64

# %%
df12.groupby("star_rating").first()
# Out:
#              Unnamed: 0                             title content_rating  \
# star_rating
# 7.4                 132                             X-Men          PG-13
# 7.5                 122                           RoboCop              R
# 7.6                  97                 The Fifth Element          PG-13
# 7.7                  79   Star Trek II: The Wrath of Khan             PG
# 7.8                  58                         Tombstone              R
# 7.9                  47                        The Killer              R
# 8.0                  37                         Furious 7          PG-13
# 8.1                  25      Kingsman: The Secret Service              R
# 8.2                  21                    V for Vendetta              R
# 8.3                  14  The Treasure of the Sierra Madre      NOT RATED
# 8.4                  10                            Aliens              R
# 8.5                   7             The Dark Knight Rises          PG-13
# ...

# %%
df12.groupby ("genre") ["star_rating"].mean()               # to finding out the mean value star_rating from genre column using.
# Out:
# genre
# Action    7.884559
# Name: star_rating, dtype: float64

# %%
df12.loc[df12["content_rating"] =="PG-13"]                     #  Another way to group function.
# Out:
#      Unnamed: 0  star_rating                                            title  \
# 0             0          9.0                                  The Dark Knight
# 1             1          8.8                                        Inception
# 7             7          8.5                            The Dark Knight Rises
# 15           15          8.3                                    Batman Begins
# 16           16          8.3               Indiana Jones and the Last Crusade
# 24           24          8.2                                     The Avengers
# 26           26          8.1                          Guardians of the Galaxy
# 30           30          8.1                             The Bourne Ultimatum
# 31           31          8.1                       X-Men: Days of Future Past
# 37           37          8.0                                        Furious 7
# 38           38          8.0                                        Star Trek
# ...

# %%
df12.loc[(df12["content_rating"] =="PG-13") & (df12["star_rating"]== 8.0)]       # using And
# Out:
#     Unnamed: 0  star_rating             title content_rating   genre  \
# 37          37          8.0         Furious 7          PG-13  Action
# 38          38          8.0         Star Trek          PG-13  Action
# 42          42          8.0          Serenity          PG-13  Action
# 43          43          8.0     Casino Royale          PG-13  Action
# 44          44          8.0         Spartacus          PG-13  Action
# 46          46          8.0  Edge of Tomorrow          PG-13  Action
#
#     duration                                        actors_list
# 37       137  [u'Vin Diesel', u'Paul Walker', u'Dwayne Johns...
# 38       127  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']
# 42       119  [u'Nathan Fillion', u'Gina Torres', u'Chiwetel...
# 43       144     [u'Daniel Craig', u'Eva Green', u'Judi Dench']
# 44       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 46       113    [u'Tom Cruise', u'Emily Blunt', u'Bill Paxton']

# %%
df12.loc[(df12["content_rating"] == "PG-13") |(df12["duration"]>125)]         # using or
# Out:
#      Unnamed: 0  star_rating                                            title  \
# 0             0          9.0                                  The Dark Knight
# 1             1          8.8                                        Inception
# 4             4          8.7                                       The Matrix
# 5             5          8.6                              Saving Private Ryan
# 7             7          8.5                            The Dark Knight Rises
# ..          ...          ...                                              ...
# 125         125          7.5                                               X2
# 126         126          7.5                                       Open Range
# 132         132          7.4                                            X-Men
# 134         134          7.4                                         The Rock
# 135         135          7.4  Master and Commander: The Far Side of the World
#
# ...

# %%
array = np.random.randint(20,40,size=(6,4))
df9=pd.DataFrame(array,columns=list("abcd"),index=list("python"))
df9
# Out:
#     a   b   c   d
# p  23  23  32  28
# y  27  32  26  20
# t  22  26  38  31
# h  29  30  38  26
# o  24  33  23  39
# n  25  37  25  29

# %%
df9.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df9.index
# Out:
# Index(['p', 'y', 't', 'h', 'o', 'n'], dtype='object')

# %%
df9.rename({"b":"E"},axis=1,inplace=True)        # inplace is means to fixed values.
df9
# Out:
#     a   E   c   d
# p  23  23  32  28
# y  27  32  26  20
# t  22  26  38  31
# h  29  30  38  26
# o  24  33  23  39
# n  25  37  25  29

# %%
df9["F"]=[5,6,7,8,9,6]
df9
# Out:
#     a   E   c   d  F
# p  23  23  32  28  5
# y  27  32  26  20  6
# t  22  26  38  31  7
# h  29  30  38  26  8
# o  24  33  23  39  9
# n  25  37  25  29  6

# %%
df9.insert(1,"z",[6,5,4,3,2,1],allow_duplicates=False)                  # inserting the new columns
df9
# Out:
#     a  z   E   c   d  F
# p  23  6  23  32  28  5
# y  27  5  32  26  20  6
# t  22  4  26  38  31  7
# h  29  3  30  38  26  8
# o  24  2  33  23  39  9
# n  25  1  37  25  29  6

# %%
df11
# Out:
#       age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 22     18    male  34.100         0     no  southeast   1137.01100
# 663    18    male  33.660         0     no  southeast   1136.39940
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 808    18    male  30.140         0     no  southeast   1131.50660
# 940    18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %%
df11.rename({"age":"Age"},axis=1,inplace=True)        # inplace is means to fixed values.
df11
# Out:
#       Age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 22     18    male  34.100         0     no  southeast   1137.01100
# 663    18    male  33.660         0     no  southeast   1136.39940
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 808    18    male  30.140         0     no  southeast   1131.50660
# 940    18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %%
df11.drop_duplicates(subset="Age",keep="first")
df11
# Out:
#       Age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 22     18    male  34.100         0     no  southeast   1137.01100
# 663    18    male  33.660         0     no  southeast   1136.39940
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 808    18    male  30.140         0     no  southeast   1131.50660
# 940    18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %%
a=df11.drop_duplicates(subset="Age",keep="first")
a
# Out:
#       Age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 1146   60    male  32.800         0    yes  southwest  52590.82939
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1062   59    male  41.140         1    yes  southeast  48970.24760
# 488    44  female  38.060         0    yes  southeast  48885.13561
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 530    57    male  42.130         1    yes  southeast  48675.51770
# 330    61  female  36.385         1    yes  northeast  48517.56315
# ...

# %%
a.values.tolist()
# Out:
# [[54, 'female', 47.41, 0, 'yes', 'southeast', 63770.42801],
#  [45, 'male', 30.36, 0, 'yes', 'southeast', 62592.87309],
#  [52, 'male', 34.485, 3, 'yes', 'northwest', 60021.39897],
#  [31, 'female', 38.095, 1, 'yes', 'northeast', 58571.07448],
#  [33, 'female', 35.53, 0, 'yes', 'northwest', 55135.40209],
#  [60, 'male', 32.8, 0, 'yes', 'southwest', 52590.82939],
#  [28, 'male', 36.4, 1, 'yes', 'southwest', 51194.55914],
#  [64, 'male', 36.96, 2, 'yes', 'southeast', 49577.6624],
#  [59, 'male', 41.14, 1, 'yes', 'southeast', 48970.2476],
#  [44, 'female', 38.06, 0, 'yes', 'southeast', 48885.13561],
#  [63, 'female', 37.7, 0, 'yes', 'southwest', 48824.45],
#  [57, 'male', 42.13, 1, 'yes', 'southeast', 48675.5177],
#  [61, 'female', 36.385, 1, 'yes', 'northeast', 48517.56315],
#  [58, 'male', 36.955, 2, 'yes', 'northwest', 47496.49445],
#  [51, 'male', 42.9, 2, 'yes', 'southeast', 47462.894],
#  [62, 'male', 30.875, 3, 'yes', 'northwest', 46718.16325],
# ...

# %%
a.to_dict()                #  json formate
# Out:
# {'Age': {543: 54,
#   1300: 45,
#   1230: 52,
#   577: 31,
#   819: 33,
#   1146: 60,
#   34: 28,
#   1241: 64,
#   1062: 59,
#   488: 44,
#   175: 63,
#   530: 57,
#   330: 61,
#   55: 58,
#   951: 51,
#   1301: 62,
#   1122: 53,
#   265: 46,
#   860: 37,
#   549: 43,
#   569: 48,
#   739: 29,
#   1047: 22,
#   1031: 55,
#   893: 47,
#   587: 34,
#   256: 56,
#   1323: 42,
#   185: 36,
#   271: 50,
#   292: 25,
#   1111: 38,
#   725: 30,
#   1124: 23,
#   697: 41,
#   682: 39,
#   667: 40,
#   558: 35,
#   1049: 49,
#   1156: 19,
#   14: 27,
#   803: 18,
#   1288: 20,
#   377: 24,
#   1249: 32,
#   373: 26,
#   1019: 21},
#  'sex': {543: 'female',
#   1300: 'male',
#   1230: 'male',
#   577: 'female',
#   819: 'female',
#   1146: 'male',
#   34: 'male',
#   1241: 'male',
#   1062: 'male',
#   488: 'female',
#   175: 'female',
#   530: 'male',
#   330: 'female',
#   55: 'male',
#   951: 'male',
#   1301: 'male',
#   1122: 'female',
#   265: 'male',
#   860: 'female',
# ...

# %%
a["bmi"].to_list()               # Array formate
# Out:
# [47.41,
#  30.36,
#  34.485,
#  38.095,
#  35.53,
#  32.8,
#  36.4,
#  36.96,
#  41.14,
#  38.06,
#  37.7,
#  42.13,
#  36.385,
#  36.955,
#  42.9,
#  30.875,
#  36.86,
#  42.35,
#  47.6,
#  46.2,
#  40.565,
#  35.5,
#  52.58,
#  35.2,
#  38.94,
#  30.21,
#  33.63,
#  40.37,
#  41.895,
#  34.2,
#  45.54,
#  38.39,
#  39.05,
#  42.75,
#  35.75,
#  35.3,
#  32.775,
#  34.105,
#  30.9,
#  44.88,
#  42.13,
#  42.24,
#  39.4,
#  40.15,
#  33.63,
#  32.9,
#  32.68]

# %%
a.to_numpy()
# Out:
# array([[54, 'female', 47.41, 0, 'yes', 'southeast', 63770.42801],
#        [45, 'male', 30.36, 0, 'yes', 'southeast', 62592.87309],
#        [52, 'male', 34.485, 3, 'yes', 'northwest', 60021.39897],
#        [31, 'female', 38.095, 1, 'yes', 'northeast', 58571.07448],
#        [33, 'female', 35.53, 0, 'yes', 'northwest', 55135.40209],
#        [60, 'male', 32.8, 0, 'yes', 'southwest', 52590.82939],
#        [28, 'male', 36.4, 1, 'yes', 'southwest', 51194.55914],
#        [64, 'male', 36.96, 2, 'yes', 'southeast', 49577.6624],
#        [59, 'male', 41.14, 1, 'yes', 'southeast', 48970.2476],
#        [44, 'female', 38.06, 0, 'yes', 'southeast', 48885.13561],
#        [63, 'female', 37.7, 0, 'yes', 'southwest', 48824.45],
#        [57, 'male', 42.13, 1, 'yes', 'southeast', 48675.5177],
#        [61, 'female', 36.385, 1, 'yes', 'northeast', 48517.56315],
#        [58, 'male', 36.955, 2, 'yes', 'northwest', 47496.49445],
#        [51, 'male', 42.9, 2, 'yes', 'southeast', 47462.894],
# ...

# %%
a.to_numpy().tolist()
# Out:
# [[54, 'female', 47.41, 0, 'yes', 'southeast', 63770.42801],
#  [45, 'male', 30.36, 0, 'yes', 'southeast', 62592.87309],
#  [52, 'male', 34.485, 3, 'yes', 'northwest', 60021.39897],
#  [31, 'female', 38.095, 1, 'yes', 'northeast', 58571.07448],
#  [33, 'female', 35.53, 0, 'yes', 'northwest', 55135.40209],
#  [60, 'male', 32.8, 0, 'yes', 'southwest', 52590.82939],
#  [28, 'male', 36.4, 1, 'yes', 'southwest', 51194.55914],
#  [64, 'male', 36.96, 2, 'yes', 'southeast', 49577.6624],
#  [59, 'male', 41.14, 1, 'yes', 'southeast', 48970.2476],
#  [44, 'female', 38.06, 0, 'yes', 'southeast', 48885.13561],
#  [63, 'female', 37.7, 0, 'yes', 'southwest', 48824.45],
#  [57, 'male', 42.13, 1, 'yes', 'southeast', 48675.5177],
#  [61, 'female', 36.385, 1, 'yes', 'northeast', 48517.56315],
#  [58, 'male', 36.955, 2, 'yes', 'northwest', 47496.49445],
#  [51, 'male', 42.9, 2, 'yes', 'southeast', 47462.894],
#  [62, 'male', 30.875, 3, 'yes', 'northwest', 46718.16325],
# ...
