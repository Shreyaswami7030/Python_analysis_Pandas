# %%
import pandas as pd
import numpy as np
import warnings
warnings. filterwarnings ("ignore")

# %%
df=pd.read_excel("Emp_Records_1.xlsx")

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %% [markdown]
# # Replace

# %%
df.replace(to_replace=1.05,value=22)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0           22.00  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace(to_replace="Nan",value="shreya")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.fillna("shreya")
# Out:
#     Emp ID First Name Age in Yrs Weight in Kgs Age in Company    Salary  \
# 0   677509       Lois      36.36          60.0          13.68  168251.0
# 1   940761     shreya      47.02          60.0           9.01   51063.0
# 2   428945        Joe      54.15          68.0           0.98   50155.0
# 3   408351      Diane      39.67          51.0           18.3    shreya
# 4   193819     shreya      40.31          58.0           4.01  117642.0
# ..     ...        ...        ...           ...            ...       ...
# 95  639892       Jose      22.82          89.0           1.05  129774.0
# 96  704709     Harold     shreya          77.0           5.93  156194.0
# 97  461593     Nicole      52.66          60.0          28.53   95673.0
# 98  392491     shreya       29.6          57.0           6.99   51015.0
# 99  495141      Tammy      38.38          55.0           2.26    shreya
#
#             City
# 0         Denver
# 1         shreya
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.replace(to_replace="Diane",value="Ganesh")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351     Ganesh       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace([1,2,3,4,5,95,96,97],103)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.fillna("Sakshi")
# Out:
#     Emp ID First Name Age in Yrs Weight in Kgs Age in Company    Salary  \
# 0   677509       Lois      36.36          60.0          13.68  168251.0
# 1   940761     Sakshi      47.02          60.0           9.01   51063.0
# 2   428945        Joe      54.15          68.0           0.98   50155.0
# 3   408351      Diane      39.67          51.0           18.3    Sakshi
# 4   193819     Sakshi      40.31          58.0           4.01  117642.0
# ..     ...        ...        ...           ...            ...       ...
# 95  639892       Jose      22.82          89.0           1.05  129774.0
# 96  704709     Harold     Sakshi          77.0           5.93  156194.0
# 97  461593     Nicole      52.66          60.0          28.53   95673.0
# 98  392491     Sakshi       29.6          57.0           6.99   51015.0
# 99  495141      Tammy      38.38          55.0           2.26    Sakshi
#
#             City
# 0         Denver
# 1         Sakshi
# 2   Michigantown
# 3       Hydetown
# ...

# %% [raw]
# df

# %%
df = df.replace([0, 1, 2, 3], 101)

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df = df.replace([0, 1, 2, 3], 101)

# %%
df.replace(["A-Za-z"],"python",regex=True)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace({"First Name":"[A-Z]"},66,regex=True)
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509        66.0       36.36           60.0           13.68  168251.0
# 1   940761         NaN       47.02           60.0            9.01   51063.0
# 2   428945        66.0       54.15           68.0            0.98   50155.0
# 3   408351        66.0       39.67           51.0           18.30       NaN
# 4   193819         NaN       40.31           58.0            4.01  117642.0
# ..     ...         ...         ...            ...             ...       ...
# 95  639892        66.0       22.82           89.0            1.05  129774.0
# 96  704709        66.0         NaN           77.0            5.93  156194.0
# 97  461593        66.0       52.66           60.0           28.53   95673.0
# 98  392491         NaN       29.60           57.0            6.99   51015.0
# 99  495141        66.0       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace(to_replace="Denver", value="Pune")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0           Pune
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace(5.93,method="ffill")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            1.05  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace(28.53,method="bfill")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0            6.99   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace("Lois",method="ffill",limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.replace("Lois",method="ffill",limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %% [markdown]
# # Interpolate

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(method='linear', axis=0, inplace=False, limit=None, limit_direction='forward', limit_area=None, downcast=None)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(method="linear")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit_direction="forward",limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit_direction="backward",limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit_direction="both",limit=3)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit_area = "inside")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30   83898.5
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       37.74           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26       NaN
#
#             City
# 0         Denver
# 1            NaN
# ...

# %%
df.interpolate(limit_area="outside")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761        NaN       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15           68.0            0.98   50155.0
# 3   408351      Diane       39.67           51.0           18.30       NaN
# 4   193819        NaN       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold         NaN           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491        NaN       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   51015.0
#
#             City
# 0         Denver
# 1            NaN
# ...
