# %%
import numpy as np

# %%
import pandas as pd

# %%
df0=pd.DataFrame()
df0
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
array = np.random.randint(10,20,size=(10,4))
array
# Out:
# array([[14, 16, 18, 17],
#        [18, 18, 17, 11],
#        [10, 11, 12, 11],
#        [16, 12, 11, 16],
#        [13, 15, 15, 19],
#        [13, 16, 10, 11],
#        [19, 17, 13, 12],
#        [12, 13, 10, 18],
#        [11, 15, 14, 17],
#        [16, 13, 10, 19]])

# %%
df1=pd.DataFrame(array)
df1
# Out:
#     0   1   2   3
# 0  14  16  18  17
# 1  18  18  17  11
# 2  10  11  12  11
# 3  16  12  11  16
# 4  13  15  15  19
# 5  13  16  10  11
# 6  19  17  13  12
# 7  12  13  10  18
# 8  11  15  14  17
# 9  16  13  10  19

# %%
list=[1,2,3,4,5]
list1=["a","b","c","d","e"]

# %%
df_l=pd.DataFrame(list,list1)
df_l
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
df_l[1]=list1      # crating a onther column to datafram
df_l
# Out:
#    0  1
# a  1  a
# b  2  b
# c  3  c
# d  4  d
# e  5  e

# %%
df=pd.read_csv("Car Sales (2) - Clients.csv")
df
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %%
df.columns
# Out:
# Index(['ClientID', 'ClientName', 'Address1', 'Address2', 'Town', 'County',
#        'PostCode', 'Region', 'OuterPostode', 'CountryID', 'ClientType',
#        'ClientSize', 'ClientSince', 'IsCreditWorthy', 'IsDealer'],
#       dtype='object')

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %%
x=df.columns

# %%
for i in x:
    print(df[i].value_counts())
    print("*"*50)
# Out:
# ClientID
# 1     1
# 17    1
# 30    1
# 29    1
# 28    1
# 27    1
# 26    1
# 25    1
# 24    1
# 23    1
# 22    1
# 21    1
# 20    1
# 19    1
# 18    1
# 16    1
# 2     1
# 15    1
# 14    1
# 13    1
# 12    1
# 11    1
# 10    1
# 9     1
# 8     1
# 7     1
# 6     1
# 5     1
# 4     1
# 3     1
# 31    1
# Name: count, dtype: int64
# **************************************************
# ClientName
# Aldo Motors                       1
# Chateau Moi                       1
# British Luxury Automobile Corp    1
# Buckingham Palace Car Services    1
# Union Jack Sports Cars            1
# Tweedy Wheels                     1
# Sporty Types Corp                 1
# BritWheels                        1
# Style ‘N Ride                     1
# Embassy Motors                    1
# Ambassador Cars                   1
# Jungfrau                          1
# Three Country Cars                1
# Carosse Des Papes                 1
# Vive la Vitesse!                  1
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=31, step=1),
#  Index(['ClientID', 'ClientName', 'Address1', 'Address2', 'Town', 'County',
#         'PostCode', 'Region', 'OuterPostode', 'CountryID', 'ClientType',
#         'ClientSize', 'ClientSince', 'IsCreditWorthy', 'IsDealer'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# ClientID            int64
# ClientName         object
# Address1           object
# Address2          float64
# Town               object
# County             object
# PostCode           object
# Region             object
# OuterPostode       object
# CountryID           int64
# ClientType         object
# ClientSize         object
# ClientSince        object
# IsCreditWorthy      int64
# IsDealer            int64
# dtype: object

# %%
df.info()    # it gives information of the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ClientID        31 non-null     int64
#  1   ClientName      31 non-null     object
#  2   Address1        18 non-null     object
#  3   Address2        0 non-null      float64
#  4   Town            31 non-null     object
#  5   County          12 non-null     object
#  6   PostCode        15 non-null     object
#  7   Region          10 non-null     object
#  8   OuterPostode    20 non-null     object
#  9   CountryID       31 non-null     int64
#  10  ClientType      31 non-null     object
#  11  ClientSize      31 non-null     object
#  12  ClientSince     31 non-null     object
#  13  IsCreditWorthy  31 non-null     int64
#  14  IsDealer        31 non-null     int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.8+ KB

# %%
df.describe()    #  it does bot give categoral data informaton ..it give only the numerical data.
# Out:
#         ClientID  Address2  CountryID  IsCreditWorthy   IsDealer
# count  31.000000       0.0  31.000000       31.000000  31.000000
# mean   16.000000       NaN   2.548387        0.806452   0.225806
# std     9.092121       NaN   1.567136        0.401610   0.425024
# min     1.000000       NaN   1.000000        0.000000   0.000000
# 25%     8.500000       NaN   1.000000        1.000000   0.000000
# 50%    16.000000       NaN   3.000000        1.000000   0.000000
# 75%    23.500000       NaN   3.000000        1.000000   0.000000
# max    31.000000       NaN   6.000000        1.000000   1.000000

# %% [markdown]
# # df.select_dtypes

# %%
df.select_dtypes(include=int)
# Out:
#     ClientID  CountryID  IsCreditWorthy  IsDealer
# 0          1          1               1         1
# 1          2          1               0         0
# 2          3          1               0         0
# 3          4          1               1         0
# 4          5          1               1         1
# 5          6          2               1         0
# 6          7          1               1         0
# 7          8          3               1         0
# 8          9          6               1         0
# 9         10          4               1         1
# 10        11          5               1         0
# 11        12          1               1         0
# 12        13          1               1         0
# 13        14          1               1         0
# 14        15          1               1         1
# 15        16          1               1         0
# 16        17          2               1         0
# 17        18          2               1         0
# ...

# %%
df.select_dtypes(include=float)
# Out:
#     Address2
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN

# %%
df.select_dtypes(include=object)
# Out:
#                         ClientName                  Address1  \
# 0                      Aldo Motors           4, Scale Street
# 1                      Honest John          99a Baker Street
# 2                    Bright Orange           17, Arcadia Way
# 3                       Cut'n'Shut             Grange Avenue
# 4                      Wheels'R'Us          Buckingham Drive
# 5                   Les Arnaqueurs         33, Rue Des Bleus
# 6                     Crippen & Co      1012 Princess Street
# 7                     Rocky Riding            5205 108th Ave
# 8      Voitures Diplomatiques S.A.                       NaN
# 9                             Karz                       NaN
# 10                 Costa Del Speed                       NaN
# 11                   Olde Englande                       NaN
# 12               Impressive Wheels                       NaN
# 13                   Smooth Riders                       NaN
# ...

# %%
df.select_dtypes(exclude=int)
# Out:
#                         ClientName                  Address1  Address2  \
# 0                      Aldo Motors           4, Scale Street       NaN
# 1                      Honest John          99a Baker Street       NaN
# 2                    Bright Orange           17, Arcadia Way       NaN
# 3                       Cut'n'Shut             Grange Avenue       NaN
# 4                      Wheels'R'Us          Buckingham Drive       NaN
# 5                   Les Arnaqueurs         33, Rue Des Bleus       NaN
# 6                     Crippen & Co      1012 Princess Street       NaN
# 7                     Rocky Riding            5205 108th Ave       NaN
# 8      Voitures Diplomatiques S.A.                       NaN       NaN
# 9                             Karz                       NaN       NaN
# 10                 Costa Del Speed                       NaN       NaN
# 11                   Olde Englande                       NaN       NaN
# ...

# %% [markdown]
# # How to acees datafram in dict

# %%
d1= {"A":[2,3,4,5,6],
     "B":[10,20,30,40,50],
     "C":np.array([100,200,300,400,500]),
     "D":np.arange(1000,1005)}
print(df1)
# Out:
#     0   1   2   3
# 0  14  16  18  17
# 1  18  18  17  11
# 2  10  11  12  11
# 3  16  12  11  16
# 4  13  15  15  19
# 5  13  16  10  11
# 6  19  17  13  12
# 7  12  13  10  18
# 8  11  15  14  17
# 9  16  13  10  19

# %%
df2=pd.DataFrame(d1)
df2.to_json("abcd.json")
df2
# Out:
#    A   B    C     D
# 0  2  10  100  1000
# 1  3  20  200  1001
# 2  4  30  300  1002
# 3  5  40  400  1003
# 4  6  50  500  1004

# %%
df2["z"]=1111            #adding the unique value from a column
df2
# Out:
#    A   B    C     D     z
# 0  2  10  100  1000  1111
# 1  3  20  200  1001  1111
# 2  4  30  300  1002  1111
# 3  5  40  400  1003  1111
# 4  6  50  500  1004  1111

# %%
df["Town"]       # showing the particular column name
# Out:
# 0               Uttoxeter
# 1                  London
# 2              Birmingham
# 3              Manchester
# 4                  London
# 5                   Paris
# 6                 Glasgow
# 7                New York
# 8                  Geneva
# 9               Stuttgart
# 10                 Madrid
# 11             Shrewsbury
# 12              Liverpool
# 13                Telford
# 14             Gloucester
# 15    Newcastle upon Tyne
# 16                   Lyon
# 17              Marseille
# 18                Avignon
# 19                  Basle
# 20                 Zurich
# 21               Bellevue
# 22                 Denver
# 23            Chevy Chase
# 24               Portland
# 25          San Francisco
# 26              Cambridge
# 27             Louisville
# 28                  Mason
# 29               Franklin
# 30             Pittsburgh
# Name: Town, dtype: object

# %%
type(df["Town"])     # to convert into series
# Out:
# pandas.core.series.Series

# %%
type(df[["Town"]])   #to convert t=into dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Town",	"County","Region"]]    # access the particular columns
# Out:
#                    Town        County                    Region
# 0             Uttoxeter        Staffs             East Midlands
# 1                London           NaN  Greater London Authority
# 2            Birmingham           NaN             West Midlands
# 3            Manchester           NaN                North West
# 4                London           NaN  Greater London Authority
# 5                 Paris           NaN                       NaN
# 6               Glasgow           NaN                       NaN
# 7              New York      New York                       NaN
# 8                Geneva           NaN                       NaN
# 9             Stuttgart           NaN                       NaN
# 10               Madrid           NaN                       NaN
# 11           Shrewsbury           NaN             West Midlands
# 12            Liverpool           NaN                North West
# 13              Telford           NaN             West Midlands
# ...

# %%
df[2:7]
# Out:
#    ClientID      ClientName              Address1  Address2        Town  \
# 2         3   Bright Orange       17, Arcadia Way       NaN  Birmingham
# 3         4      Cut'n'Shut         Grange Avenue       NaN  Manchester
# 4         5     Wheels'R'Us      Buckingham Drive       NaN      London
# 5         6  Les Arnaqueurs     33, Rue Des Bleus       NaN       Paris
# 6         7    Crippen & Co  1012 Princess Street       NaN     Glasgow
#
#   County PostCode                    Region OuterPostode  CountryID  \
# 2    NaN  B1 50AZ             West Midlands            B          1
# 3    NaN   M1 5AZ                North West            M          1
# 4    NaN  SE1 4YY  Greater London Authority           NE          1
# 5    NaN    75010                       NaN          NaN          2
# 6    NaN   G1 8GH                       NaN          NaN          1
#
#   ClientType ClientSize ClientSince  IsCreditWorthy  IsDealer
# ...

# %%
df[2:7:2]
# Out:
#    ClientID     ClientName              Address1  Address2        Town County  \
# 2         3  Bright Orange       17, Arcadia Way       NaN  Birmingham    NaN
# 4         5    Wheels'R'Us      Buckingham Drive       NaN      London    NaN
# 6         7   Crippen & Co  1012 Princess Street       NaN     Glasgow    NaN
#
#   PostCode                    Region OuterPostode  CountryID ClientType  \
# 2  B1 50AZ             West Midlands            B          1     Dealer
# 4  SE1 4YY  Greater London Authority           NE          1     Dealer
# 6   G1 8GH                       NaN          NaN          1     Dealer
#
#   ClientSize ClientSince  IsCreditWorthy  IsDealer
# 2      Large    04/01/05               0         0
# 4      Large    05/31/07               1         1
# 6      Large    10/15/09               1         0

# %% [markdown]
# # Access rows and column

# %% [markdown]
# # 1.iloc  :- Index location

# %%
df.iloc[:,:]     #all rows and column
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %%
df.iloc[2:5:]   #it show only row
# Out:
#    ClientID     ClientName          Address1  Address2        Town County  \
# 2         3  Bright Orange   17, Arcadia Way       NaN  Birmingham    NaN
# 3         4     Cut'n'Shut     Grange Avenue       NaN  Manchester    NaN
# 4         5    Wheels'R'Us  Buckingham Drive       NaN      London    NaN
#
#   PostCode                    Region OuterPostode  CountryID ClientType  \
# 2  B1 50AZ             West Midlands            B          1     Dealer
# 3   M1 5AZ                North West            M          1     Dealer
# 4  SE1 4YY  Greater London Authority           NE          1     Dealer
#
#   ClientSize ClientSince  IsCreditWorthy  IsDealer
# 2      Large    04/01/05               0         0
# 3      Small    01/01/10               1         0
# 4      Large    05/31/07               1         1

# %%
df.iloc[2:6,1:5]     # it show row as well as column
# Out:
#        ClientName           Address1  Address2        Town
# 2   Bright Orange    17, Arcadia Way       NaN  Birmingham
# 3      Cut'n'Shut      Grange Avenue       NaN  Manchester
# 4     Wheels'R'Us   Buckingham Drive       NaN      London
# 5  Les Arnaqueurs  33, Rue Des Bleus       NaN       Paris

# %%
df.iloc[2:6,1:5:2]   #  step size : give only row index
# Out:
#        ClientName  Address2
# 2   Bright Orange       NaN
# 3      Cut'n'Shut       NaN
# 4     Wheels'R'Us       NaN
# 5  Les Arnaqueurs       NaN

# %%
df.iloc[2:6,1:5:3]
# Out:
#        ClientName        Town
# 2   Bright Orange  Birmingham
# 3      Cut'n'Shut  Manchester
# 4     Wheels'R'Us      London
# 5  Les Arnaqueurs       Paris

# %%
df.iloc[5]                               # 5th index row for all the column
# Out:
# ClientID                          6
# ClientName           Les Arnaqueurs
# Address1          33, Rue Des Bleus
# Address2                        NaN
# Town                          Paris
# County                          NaN
# PostCode                      75010
# Region                          NaN
# OuterPostode                    NaN
# CountryID                         2
# ClientType                   Dealer
# ClientSize                    Large
# ClientSince                02/15/03
# IsCreditWorthy                    1
# IsDealer                          0
# Name: 5, dtype: object

# %%
df.iloc[5:6]
# Out:
#    ClientID      ClientName           Address1  Address2   Town County  \
# 5         6  Les Arnaqueurs  33, Rue Des Bleus       NaN  Paris    NaN
#
#   PostCode Region OuterPostode  CountryID ClientType ClientSize ClientSince  \
# 5    75010    NaN          NaN          2     Dealer      Large    02/15/03
#
#    IsCreditWorthy  IsDealer
# 5               1         0

# %%
df.iloc[1,1]     # it gives next value
# Out:
# 'Honest John'

# %%
df.iloc[-10:,-3:]
# Out:
#    ClientSince  IsCreditWorthy  IsDealer
# 21    04/01/13               1         0
# 22    04/01/13               1         0
# 23    04/01/13               1         0
# 24    04/01/13               0         1
# 25    04/01/13               0         0
# 26    04/01/13               1         0
# 27    04/01/13               0         0
# 28    04/01/13               1         0
# 29    04/01/13               0         1
# 30    04/01/13               1         0

# %%
df.iloc[-10,-3]
# Out:
# '04/01/13'

# %%
df.iloc[-10:,:]
# Out:
#     ClientID                      ClientName                  Address1  \
# 21        22                 Ambassador Cars           11 Times Square
# 22        23                  Embassy Motors      57595 Technology Way
# 23        24                   Style ‘N Ride        5404 Wisconsin Ave
# 24        25                      BritWheels   1414 NW Northrup Street
# 25        26               Sporty Types Corp       13550 Market Street
# 26        27                   Tweedy Wheels         One Oxford Center
# 27        28          Union Jack Sports Cars  9900 Corporate Campus Dr
# 28        29  Buckingham Palace Car Services           4605 Duke Drive
# 29        30  British Luxury Automobile Corp        2555 Meridian Blvd
# 30        31                Classy Car Sales            30 Isabella St
#
#     Address2           Town        County PostCode Region OuterPostode  \
# 21       NaN       Bellevue    Washington      NaN    NaN           WA
# ...

# %%
df.iloc[:,-5:]
# Out:
#     ClientType ClientSize ClientSince  IsCreditWorthy  IsDealer
# 0   Wholesaler      Large    01/04/98               1         1
# 1       Dealer      Large    01/01/00               0         0
# 2       Dealer      Large    04/01/05               0         0
# 3       Dealer      Small    01/01/10               1         0
# 4       Dealer      Large    05/31/07               1         1
# 5       Dealer      Large    02/15/03               1         0
# 6       Dealer      Large    10/15/09               1         0
# 7       Dealer      Large    10/15/09               1         0
# 8   Wholesaler      Large    10/15/09               1         0
# 9       Dealer      Small    05/31/06               1         1
# 10      Dealer      Small    05/31/12               1         0
# 11      Dealer      Small    05/31/12               1         0
# 12  Wholesaler      Large    05/31/07               1         0
# 13      Dealer      Large    05/31/08               1         0
# ...

# %%
df.iloc[2:3:]
# Out:
#    ClientID     ClientName         Address1  Address2        Town County  \
# 2         3  Bright Orange  17, Arcadia Way       NaN  Birmingham    NaN
#
#   PostCode         Region OuterPostode  CountryID ClientType ClientSize  \
# 2  B1 50AZ  West Midlands            B          1     Dealer      Large
#
#   ClientSince  IsCreditWorthy  IsDealer
# 2    04/01/05               0         0

# %%
df.head()    # first 10 record
# Out:
#    ClientID     ClientName          Address1  Address2        Town  County  \
# 0         1    Aldo Motors   4, Scale Street       NaN   Uttoxeter  Staffs
# 1         2    Honest John  99a Baker Street       NaN      London     NaN
# 2         3  Bright Orange   17, Arcadia Way       NaN  Birmingham     NaN
# 3         4     Cut'n'Shut     Grange Avenue       NaN  Manchester     NaN
# 4         5    Wheels'R'Us  Buckingham Drive       NaN      London     NaN
#
#     PostCode                    Region OuterPostode  CountryID  ClientType  \
# 0  ST17 99RZ             East Midlands           ST          1  Wholesaler
# 1    NSW1 1A  Greater London Authority           EC          1      Dealer
# 2    B1 50AZ             West Midlands            B          1      Dealer
# 3     M1 5AZ                North West            M          1      Dealer
# 4    SE1 4YY  Greater London Authority           NE          1      Dealer
#
#   ClientSize ClientSince  IsCreditWorthy  IsDealer
# ...

# %%
df.tail()    #last  5 record
# Out:
#     ClientID                      ClientName                  Address1  \
# 26        27                   Tweedy Wheels         One Oxford Center
# 27        28          Union Jack Sports Cars  9900 Corporate Campus Dr
# 28        29  Buckingham Palace Car Services           4605 Duke Drive
# 29        30  British Luxury Automobile Corp        2555 Meridian Blvd
# 30        31                Classy Car Sales            30 Isabella St
#
#     Address2        Town        County PostCode Region OuterPostode  \
# 26       NaN   Cambridge  Massahussets      NaN    NaN           MA
# 27       NaN  Louisville      Kentucky      NaN    NaN           KY
# 28       NaN       Mason          Ohio      NaN    NaN           OH
# 29       NaN    Franklin      Tennesee      NaN    NaN           TN
# 30       NaN  Pittsburgh  Pennsylvania      NaN    NaN           PA
#
#     CountryID  ClientType ClientSize ClientSince  IsCreditWorthy  IsDealer
# ...

# %%
df.tail(10)        # difference bertwwen head() and tail()
# Out:
#     ClientID                      ClientName                  Address1  \
# 21        22                 Ambassador Cars           11 Times Square
# 22        23                  Embassy Motors      57595 Technology Way
# 23        24                   Style ‘N Ride        5404 Wisconsin Ave
# 24        25                      BritWheels   1414 NW Northrup Street
# 25        26               Sporty Types Corp       13550 Market Street
# 26        27                   Tweedy Wheels         One Oxford Center
# 27        28          Union Jack Sports Cars  9900 Corporate Campus Dr
# 28        29  Buckingham Palace Car Services           4605 Duke Drive
# 29        30  British Luxury Automobile Corp        2555 Meridian Blvd
# 30        31                Classy Car Sales            30 Isabella St
#
#     Address2           Town        County PostCode Region OuterPostode  \
# 21       NaN       Bellevue    Washington      NaN    NaN           WA
# ...

# %% [markdown]
# # 2. dfloc

# %% [raw]
# label of rows and labels of column actual values of rows and columns

# %%
df.loc[1:4,"CountryID":"ClientSince"]    # range of column label
# Out:
#    CountryID ClientType ClientSize ClientSince
# 1          1     Dealer      Large    01/01/00
# 2          1     Dealer      Large    04/01/05
# 3          1     Dealer      Small    01/01/10
# 4          1     Dealer      Large    05/31/07

# %%
df.loc[[10,20,30],["CountryID","ClientSince","ClientSize"]]
# Out:
#     CountryID ClientSince ClientSize
# 10          5    05/31/12      Small
# 20          6    01/01/12      Small
# 30          3    04/01/13      Small

# %%
len(df)    # length of data frame
# Out:
# 31

# %%
df.shape
# Out:
# (31, 15)

# %% [markdown]
# # change the column name

# %%
df.columns=list("ABCDEFGHIJKLMNO")    # using list constructor
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 df.columns=list("ABCDEFGHIJKLMNO")    # using list constructor
#       2 df
#
# TypeError: 'list' object is not callable

# %%
df.index=list("PYTHON")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[218], line 1
# ----> 1 df.index=list("PYTHON")
#       2 df
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # Dataframe to csv files

# %%
df.to_csv("created_data.csv")            # crate csv
df
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %%
# remove index from dataframe
df.to_csv("crated_data.csv", index=False)
df
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %% [markdown]
# # Create Excel

# %%
df.to_excel("New_created_data.xlsx")
df
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %% [markdown]
# # To json

# %%
df.to_json("abcd.json")   # orient --> "split","records","index","columns"
df
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                       NaN
# 9         10                            Karz                       NaN
# 10        11                 Costa Del Speed                       NaN
# 11        12                   Olde Englande                       NaN
# ...

# %%
df3=pd.read_json("abcd.json")            # read the json files
df3
# Out:
#     ClientID                      ClientName                  Address1  \
# 0          1                     Aldo Motors           4, Scale Street
# 1          2                     Honest John          99a Baker Street
# 2          3                   Bright Orange           17, Arcadia Way
# 3          4                      Cut'n'Shut             Grange Avenue
# 4          5                     Wheels'R'Us          Buckingham Drive
# 5          6                  Les Arnaqueurs         33, Rue Des Bleus
# 6          7                    Crippen & Co      1012 Princess Street
# 7          8                    Rocky Riding            5205 108th Ave
# 8          9     Voitures Diplomatiques S.A.                      None
# 9         10                            Karz                      None
# 10        11                 Costa Del Speed                      None
# 11        12                   Olde Englande                      None
# ...

# %% [markdown]
# # Handling of Missing values

# %% [raw]
# 1. Detect Missing values:
#
# 1.df.isna()
# 2.df.isnull()
# 3.df.isna.sum()
# 4. df.isna.mean() *100

# %%
df.isna()
# Out:
#     ClientID  ClientName  Address1  Address2   Town  County  PostCode  Region  \
# 0      False       False     False      True  False   False     False   False
# 1      False       False     False      True  False    True     False   False
# 2      False       False     False      True  False    True     False   False
# 3      False       False     False      True  False    True     False   False
# 4      False       False     False      True  False    True     False   False
# 5      False       False     False      True  False    True     False    True
# 6      False       False     False      True  False    True     False    True
# 7      False       False     False      True  False   False      True    True
# 8      False       False      True      True  False    True      True    True
# 9      False       False      True      True  False    True      True    True
# 10     False       False      True      True  False    True      True    True
# ...

# %%
df.isnull()
# Out:
#     ClientID  ClientName  Address1  Address2   Town  County  PostCode  Region  \
# 0      False       False     False      True  False   False     False   False
# 1      False       False     False      True  False    True     False   False
# 2      False       False     False      True  False    True     False   False
# 3      False       False     False      True  False    True     False   False
# 4      False       False     False      True  False    True     False   False
# 5      False       False     False      True  False    True     False    True
# 6      False       False     False      True  False    True     False    True
# 7      False       False     False      True  False   False      True    True
# 8      False       False      True      True  False    True      True    True
# 9      False       False      True      True  False    True      True    True
# 10     False       False      True      True  False    True      True    True
# ...
